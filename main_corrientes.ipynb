# %%
import os
from services.DataFrame_maker import *
from services.InteractivePlotter import InteractivePlotterTk
from services.carga_de_datos import *   
from services.utilidades import *

# %%
# Recargar módulos locales (ejecutar esta celda cuando cambies código en services/)
import importlib
import sys

# Lista de módulos locales a recargar
modulos_locales = [
    'services.carga_de_datos',
    'services.DataFrame_maker',
    'services.prueba',
    'services.utilidades',
    'services.get_tspan',
    'services.polar2uv',
    'services.uv2polar'
]

for modulo in modulos_locales:
    if modulo in sys.modules:
        importlib.reload(sys.modules[modulo])
        print(f"✓ Recargado: {modulo}")
    else:
        print(f"- No cargado: {modulo}")

# Re-importar después de recargar
from services.DataFrame_maker import *
from services.InteractivePlotter import InteractivePlotterTk
from services.carga_de_datos import *

print("\n¡Módulos locales recargados!")
# Out:
# ✓ Recargado: services.carga_de_datos
# ✓ Recargado: services.DataFrame_maker
# - No cargado: services.prueba
# ✓ Recargado: services.utilidades
# ✓ Recargado: services.get_tspan
# - No cargado: services.polar2uv
# ✓ Recargado: services.uv2polar
#
# ¡Módulos locales recargados!

# %%
# %matplotlib tk

# %%
# # Configuraciones [Acá se indica que carpetas, mensaje y tipo de mensaje se cargará] 
# carpetas = [#"//192.168.15.249/Med_2025-2026/Reportes_Edit/Reporte_1.3/2026/03. Marzo/BOT1-01-T80/DATOS"] #,
#             "//192.168.15.249/Med_2025-2026/Reportes_Edit/Reporte_1.2/2026/03. Marzo/BOT1-01-T80/DATOS"]
# tipos = ["realt"] # realt o mem # Se debe colocar un tipo por cada archivo cargado (esto es para poder comparar una localización de mem contra otra de realt)
# msg = 4
ruta_a_carpeta = "C:\\Users\\Atmosfera\\Desktop\\datos_procesados\\revisiones\\2026\\marzo\\BOT1-01-T80\\DATOS"
fi = "06/11/2025 16:00" # Fecha inicial de todo el estudio 20251106-20260306
ff = "06/03/2026 23:00" # Fecha final de todo el estudio
dict_de_boyas = {}

# %% [markdown]
# ### 1. ADCP

# %%
# # 1.1. Cargar memoria csv
# nombre = "BOT1-01-T80_CSV"
# archivos_csv = ["2025_11_14_00_04_45_avgdA0_avgd.csv"]
# fecha_de_inicio = "16/11/2025 19:00"
# fecha_final = "08/02/2026 21:00"
# df_csv = cargar_memoria_adcp_csv(ruta_a_carpeta, archivos_csv, fecha_de_inicio, fecha_final)
# dict_de_boyas[nombre] = df_csv # Guardo el dataframe dentro del diccionario de boyas.
# df_csv.head(2)

# %%
# 1.2. Cargar telemetría .dat
nombre = "BOT1-01-T80_DAT"
nombre_de_archivo = "BOT1-01-T80-MENSAJE4-SIG500DW-NS104517-Z0.54-REALT-20251106-20260306-RAW.dat"
indices = crear_indices_para_crudos_dat_o_txt("realt")
df_dat = cargar_telemetria_adcp_dat(ruta_a_carpeta, nombre_de_archivo, indices)
dict_de_boyas[nombre] = df_dat # Guardo el dataframe dentro del diccionario de boyas.
df_dat.head(2)
# Out:
#                 tspan temp_adpc  rap_1      dir_1  rap_2  dir_2  rap_3  \
# 0 2025-11-06 16:00:00     29.10   0.26  32.700001   0.24   36.5   0.23
# 1 2025-11-06 17:00:00     29.15   0.23  70.300003   0.25   66.5   0.24
#
#        dir_3  rap_4      dir_4  ...  rap_13      dir_13  rap_14  dir_14  \
# 0  45.000000   0.23  52.299999  ...    0.22  105.099998   46.34   225.0
# 1  65.699997   0.22  63.299999  ...   46.34  225.000000   46.34   225.0
#
#    rap_15  dir_15  rap_16  dir_16  rap_17  dir_17
# 0   46.34   225.0   46.34   225.0   46.34   225.0
# 1   46.34   225.0   46.34   225.0   46.34   225.0
#
# [2 rows x 36 columns]

# %%
# 1.3. Cargar telemetría cruda_unida .pkl (memoria unida con telemetría)
nombre = "BOT1-01-T80_pkl_C"
nombre_de_archivo = "msj4_crudo_unido_realt_2025110616_2026030623.pkl"
df_pkl_C, _ = cargar_pickle_adcp(ruta_a_carpeta, nombre_de_archivo)
dict_de_boyas[nombre] = df_pkl_C # Guardo el dataframe dentro del diccionario de boyas.
df_pkl_C.head(2)
# Out:
#                 tspan  rap_1  dir_1  rap_2  dir_2  rap_3  dir_3  rap_4  dir_4  \
# 0 2025-11-06 16:00:00   0.26   32.7   0.24   36.5   0.23   45.0   0.23   52.3
# 1 2025-11-06 17:00:00   0.23   70.3   0.25   66.5   0.24   65.7   0.22   63.3
#
#    rap_5  ...  rap_14  dir_14  rap_15  dir_15  rap_16  dir_16  rap_17  dir_17  \
# 0   0.23  ...   46.34   225.0   46.34   225.0   46.34   225.0   46.34   225.0
# 1   0.23  ...   46.34   225.0   46.34   225.0   46.34   225.0   46.34   225.0
#
#    temp_adcp  temperatura_mct
# 0      29.10             28.8
# 1      29.15             28.9
#
# [2 rows x 37 columns]

# %%
# 1.3. Cargar datos validados .pkl
nombre = "BOT1-01-T80_pkl_V"
nombre_de_archivo = "msj4_validados_realt_2025110616_2026030623.pkl"
df_pkl_V, _ = cargar_pickle_adcp(ruta_a_carpeta, nombre_de_archivo)
dict_de_boyas[nombre] = df_pkl_V # Guardo el dataframe dentro
df_pkl_V.head(2)
# Out:
#                 tspan  rap_1  dir_1  rap_2  dir_2  rap_3  dir_3  rap_4  dir_4  \
# 0 2025-11-06 16:00:00   0.26   32.7   0.24   36.5   0.23   45.0   0.23   52.3
# 1 2025-11-06 17:00:00   0.23   70.3   0.25   66.5   0.24   65.7   0.22   63.3
#
#    rap_5  ...  rap_12  dir_12  rap_13  dir_13  rap_14  dir_14  rap_15  dir_15  \
# 0   0.23  ...    0.23    98.1    0.22   105.1     NaN     NaN     NaN     NaN
# 1   0.23  ...    0.23   138.3     NaN     NaN     NaN     NaN     NaN     NaN
#
#    temp_adcp  temperatura_mct
# 0      29.10             28.8
# 1      29.15             28.9
#
# [2 rows x 33 columns]

# %%
# 1.4. Cargar NETCDF de corrientes
nombre = "BOT1-01-T80_NC"
nombre_de_archivo = "BOT1-01-T80-SIG500DW-NS104517-Z0.54-REALT-20251106-20260306.nc"
df_nc = cargar_nc_adcp(ruta_a_carpeta, nombre_de_archivo)
dict_de_boyas[nombre] = df_nc # Guardo el dataframe dentro del diccionario de boyas.
df_nc.head(2)
# Out:
#                 tspan  temp_adcp  rap_1      dir_1  rap_2      dir_2  rap_3  \
# 0 2025-11-06 16:00:00      29.10   0.26  32.700001   0.24  36.500000   0.23
# 1 2025-11-06 17:00:00      29.15   0.23  70.299995   0.25  66.499992   0.24
#
#        dir_3  rap_4      dir_4  ...  rap_11      dir_11  rap_12      dir_12  \
# 0  45.000000   0.23  52.299995  ...    0.22   78.900002    0.23   98.099991
# 1  65.699997   0.22  63.299995  ...    0.21  114.599998    0.23  138.300003
#
#    rap_13      dir_13  rap_14  dir_14  rap_15  dir_15
# 0    0.22  105.099991     NaN     NaN     NaN     NaN
# 1     NaN         NaN     NaN     NaN     NaN     NaN
#
# [2 rows x 32 columns]

# %%
# Crear el diccionario de boyas con los dataframes cargados
df = crear_dataframe_de_boyas(dict_de_boyas)
# Out:
# Index(['tspan', 'temp_adpc_BOT1-01-T80_DAT', 'rap_1_BOT1-01-T80_DAT',
#        'dir_1_BOT1-01-T80_DAT', 'rap_2_BOT1-01-T80_DAT',
#        'dir_2_BOT1-01-T80_DAT', 'rap_3_BOT1-01-T80_DAT',
#        'dir_3_BOT1-01-T80_DAT', 'rap_4_BOT1-01-T80_DAT',
#        'dir_4_BOT1-01-T80_DAT',
#        ...
#        'rap_11_BOT1-01-T80_NC', 'dir_11_BOT1-01-T80_NC',
#        'rap_12_BOT1-01-T80_NC', 'dir_12_BOT1-01-T80_NC',
#        'rap_13_BOT1-01-T80_NC', 'dir_13_BOT1-01-T80_NC',
#        'rap_14_BOT1-01-T80_NC', 'dir_14_BOT1-01-T80_NC',
#        'rap_15_BOT1-01-T80_NC', 'dir_15_BOT1-01-T80_NC'],
#       dtype='object', length=135)

# %%
app = InteractivePlotterTk(df)
# Iniciar el bucle de la aplicación
app.root.mainloop()

# NOTAS PENDIENTES:
# - Arreglar que al eliminar puntos para que no tenga límite el historial de deshacer
# - Arreglar para que solo se grafiquen las columnas elegidas por el usuario
# - Agregar una función que grafique las variables de Rap y Dir --> sería algo como que df.iloc[idx,col][prof]
# - Arreglar el caso de cuando el usuario elimina puntos de Rap o Dir colocar U y V como nans --> df.iloc[idx,col][prof] = np.nan
# - Agregar la funcionalidad de guardar el DataFrame corregido en un archivo .csv o .xlsx, pkl
# - Agregar la funcionalidad de devolver puntos eliminados (no deshacer la última acción, sino devolver puntos específicos)
